# %% [markdown]
# <a href="https://colab.research.google.com/github/arunucek/algorithm/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import matplotlib.pyplot as plt

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

def measure_search_time(n, target):
    arr = list(range(n))
    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()
    return end_time - start_time
n_values = range(100, 2001, 100)
times = []

target = -1
for n in n_values:
    time_taken = measure_search_time(n, target)
    times.append(time_taken)


plt.plot(n_values, times, marker='o')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Linear Search Time vs Number of Elements')
plt.grid(True)
plt.show()
